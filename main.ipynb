# %%
# %matplotlib inline
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import fastText
ft_model = fastText.load_model('../eml2vec/wiki.ru/wiki.ru.bin')

# %%
import re
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
bad_pos = {'CONJ', 'PREP', 'NPRO', 'PRCL'}

def clean_text(text):
    text = re.sub(r'[^\w\s]',' ', text)
    text = text.lower()
    clean_text = []
    for word in text.split():
        if not word:
            continue
#         if morph.parse(word)[0].tag.POS in bad_pos:
#             continue
        clean_text.append(word)
    return ' '.join(clean_text)

# %%
q2a = []
with open('faq.txt') as faq_input:
    for i, line in enumerate(faq_input):
        if i % 2 == 0:
            q2a.append([line.rstrip()])
        else:
            q2a[-1].append(line.rstrip())

# %%
df = pd.DataFrame(data=q2a, columns=['q_raw', 'a'])
df['q_a'] = df.apply(lambda row: row['q_raw'] + ' ' + row['a'], axis=1)
df['q'] = df['q_raw'].map(clean_text)
df['a'] = df['a'].map(clean_text)
df['q_a'] = df['q_a'].map(clean_text)

# %%
from gensim.models.doc2vec import TaggedDocument, Doc2Vec
import multiprocessing
from pprint import pprint

df['q_a_tagged'] = df.apply(
    lambda row: TaggedDocument(words=row['q_a'], tags=[row.name]), axis=1)

doc2vec_model = Doc2Vec(df['q_a_tagged'].values, workers=1, size=5, iter=20, dm=1)
df['q_a_tagged_vec'] = [doc2vec_model.infer_vector(doc.words, steps=20) for doc in df['q_a_tagged']]

# %%
def get_sentence_vector(sentence):
    vec = np.zeros_like(ft_model.get_word_vector('привет'))
    sentence_split = sentence.split() 
    for word in sentence.split():
        vec += ft_model.get_word_vector(word) / len(sentence_split)
    return vec

# %%
df['q_vec'] = df['q'].map(ft_model.get_sentence_vector)
df['q_a_vec'] = df['q_a'].map(ft_model.get_sentence_vector)
df['q_vec'] = df['q'].map(ft_model.get_sentence_vector)
df['q_a_vec'] = df['q_a'].map(ft_model.get_sentence_vector)
df['q_a_w_vec'] = df.apply(lambda row: list(ft_model.get_sentence_vector(row['q']) * 0.2 + 
                                              ft_model.get_sentence_vector(row['a']) * 0.8), axis=1)
df['q_vec_unnormed'] = df['q'].map(get_sentence_vector)
df['q_a_vec_unnormed'] = df['q_a'].map(get_sentence_vector)
df['q_a_w_vec_unnormed'] = df.apply(lambda row: list(get_sentence_vector(row['q']) * 0.2 + 
                                                      get_sentence_vector(row['a']) * 0.8), axis=1)

df['q_a_concat_vec_unnormed'] = df.apply(lambda row: 
                                               list(np.hstack((get_sentence_vector(row['q']),
                                                               get_sentence_vector(row['a']) / 4))), axis=1)

# %%
df_test = pd.DataFrame(
    data=[['как уйти в отпуск', 'Как запланировать отпуск?', 'Как запланировать отпуск?'],
          ['компенсируйте мне отпуск пожалуйста', 'сделай мне одолжение', 'Возможна ли денежная компенсация за неиспользованный отпуск?'],
          ['можно ли оформлять отпуск на выходные', 'Можно ли планировать отпуск на выходные дни?', 'Можно ли планировать отпуск на выходные дни?'],
          ['как сделать пропуск', 'Когда требуется оформление пропуска и как это сделать?', 'Когда требуется оформление пропуска и как это сделать?'],
          ['можно ли не ходить в отпуск', 'Обязательно ли сотруднику идти в отпуск?', 'Обязательно ли сотруднику идти в отпуск?'],
          ['здравствуйте', 'привет привет', 'привет привет'],
          ['как получить зарплатную карту', 'В каком порядке выдаются зарплатные карты?', 'В каком порядке выдаются зарплатные карты?'],
          ['можно ли сделать больничный в отпуске', 'Обязательно ли сотруднику идти в отпуск?', 'Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год?'],
          ['как получить копию трудового договора', 'Когда и как можно забрать свой экземпляр трудового договора?', 'Когда и как можно забрать свой экземпляр трудового договора?'],
          ['за сколько дней нужно подавать заявку на отпуск?', 'Как запланировать отпуск?', 'За сколько дней можно оформить отпуск?'],
          ['сколько дней отпуска можно взять единовременно', 'Какое количество дней отпуска можно взять (мин/макс)?', 'Какое количество дней отпуска можно взять (мин/макс)?'],
          ['когда выдаются премии?', 'Где можно подробнее ознакомиться с правилами годового премирования?', 'Где можно подробнее ознакомиться с правилами годового премирования?'],
          ['что делать если я заболел', 'Какой порядок вынесения работнику дисциплинарного взыскания?', 'Как оформляется больничный лист'],
          ['отменяются ли дни отпуска, которые пересекаются с больничным?', 'Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести','Если во время отпуска работник заболел'],
          ['можно ли оформить отпуск на выходные?', 'Можно ли планировать отпуск на выходные дни?', 'Можно ли планировать отпуск на выходные дни?'],
          ['даются ли отгулы за сдачу крови?', 'Возможна ли денежная компенсация за неиспользованный отпуск?', 'Отпуск для доноров: сколько дней полагается и как они оплачиваются?'],
          ['есть ли дополнительный отпуск тем, кто работал в Чернобыле?', 'ты кто', 'Как оформяется отпуск чернобыльцам?'],
         ],
        columns=['user_q', 'q_autof', 'q_best'])

df_test['user_q_vec'] = df_test['user_q'].map(clean_text).map(ft_model.get_sentence_vector)
df_test['user_q_vec_unnormed'] = df_test['user_q'].map(clean_text).map(get_sentence_vector)
df_test['user_q_concat_vec_unnormed'] = df_test['user_q'].map(clean_text)\
    .map(get_sentence_vector).map(lambda x: np.hstack((x,x)))

# %%
df_test['user_q_tagged'] = df_test.apply(
    lambda row: TaggedDocument(words=row['user_q'], tags=[row.name]), axis=1)

df_test['user_q_tagged_vec'] = [doc2vec_model.infer_vector(doc.words, steps=20) for doc in df_test['user_q_tagged']]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1, weights='distance')

def get_nearest(neighborhood, user_queries):
    knn.fit(np.vstack(neighborhood.values), np.zeros(len(neighborhood)))
    knn_result = knn.kneighbors(np.vstack(user_queries.values), n_neighbors=1)
    return df['q_raw'][knn_result[1][:,0]], knn_result[0][:,0]

experiments = {}

experiments['q'] = get_nearest(df['q_vec'], df_test['user_q_vec'])
experiments['q_a'] = get_nearest(df['q_a_vec'], df_test['user_q_vec'])
experiments['q_a_w'] = get_nearest(df['q_a_w_vec'], df_test['user_q_vec'])
experiments['q_unnormed'] = get_nearest(df['q_vec_unnormed'], df_test['user_q_vec_unnormed'])
experiments['q_a_unnormed'] = get_nearest(df['q_a_vec_unnormed'], df_test['user_q_vec_unnormed'])
experiments['q_a_w_unnormed'] = \
    get_nearest(df['q_a_w_vec_unnormed'], df_test['user_q_vec_unnormed'])
experiments['q_a_concat_unnormed'] = \
    get_nearest(df['q_a_concat_vec_unnormed'], df_test['user_q_concat_vec_unnormed'])
experiments['q_a_doc2vec'] = \
    get_nearest(df['q_a_tagged_vec'], df_test['user_q_tagged_vec'])

# %%
from collections import defaultdict
experiment2score = defaultdict(int)

def is_match_correct(match, best_match):
    if match.startswith(best_match):
        return '+'
    return '-'


for i, (user_q, q_best, q_autof) in enumerate(zip(df_test['user_q'], df_test['q_best'], df_test['q_autof'])):
    print('User query:'.ljust(22), user_q)
    print('Best match:'.ljust(20), '+', q_best)
    print('AutoF:'.ljust(20), is_match_correct(q_autof, q_best), q_autof)
    if is_match_correct(q_autof, q_best) == '+':
        experiment2score['AutoF'] += 1
    
    for exper_name, (q_matches, distances) in experiments.items():
#         if exper_name != 'q_a_w':
#             continue
        q_match, distance = q_matches.iloc[i], distances[i]
        print(exper_name.ljust(20), is_match_correct(q_match, q_best), q_match, round(distance, 4))
        if is_match_correct(q_match, q_best) == '+':
            experiment2score[exper_name] += 1
    print()
    
    
print('\nScores ({} questions):'.format(len(df_test)))
for exper_name, score in experiment2score.items():
    print(score, exper_name)
# Out:
# User query:            как уйти в отпуск
# Best match:          + Как запланировать отпуск?
# AutoF:               + Как запланировать отпуск?
# q                    + Как запланировать отпуск? 0.3848
# q_a                  - Как оформяется отпуск чернобыльцам? 0.4067
# q_a_w                - Как оформяется отпуск чернобыльцам? 0.3916
# q_unnormed           + Как запланировать отпуск? 1.5488
# q_a_unnormed         - Как оформяется отпуск чернобыльцам? 1.5606
# q_a_w_unnormed       - Как оформяется отпуск чернобыльцам? 1.5179
# q_a_concat_unnormed  + Как запланировать отпуск? 2.6557
# q_a_doc2vec          - ты милая 0.1112
#
# User query:            компенсируйте мне отпуск пожалуйста
# Best match:          + Возможна ли денежная компенсация за неиспользованный отпуск?
# AutoF:               - сделай мне одолжение
# q                    - Могу ли я добавить дополнительного согласователя при планировании отпуска? 0.5204
# q_a                  - уточни о чём ты 0.4921
# q_a_w                - уточни о чём ты 0.4882
# q_unnormed           - За сколько дней можно оформить отпуск? 2.359
# q_a_unnormed         - молодец 2.2688
# q_a_w_unnormed       - молодец 2.1233
# q_a_concat_unnormed  - За сколько дней можно оформить отпуск? 3.9182
# q_a_doc2vec          - ты скучный 0.1973
#
# User query:            можно ли оформлять отпуск на выходные
# Best match:          + Можно ли планировать отпуск на выходные дни?
# AutoF:               + Можно ли планировать отпуск на выходные дни?
# q                    + Можно ли планировать отпуск на выходные дни? 0.2164
# q_a                  + Можно ли планировать отпуск на выходные дни? 0.331
# q_a_w                + Можно ли планировать отпуск на выходные дни? 0.3381
# q_unnormed           + Можно ли планировать отпуск на выходные дни? 0.9869
# q_a_unnormed         + Можно ли планировать отпуск на выходные дни? 1.433
# q_a_w_unnormed       + Можно ли планировать отпуск на выходные дни? 1.4611
# q_a_concat_unnormed  + Можно ли планировать отпуск на выходные дни? 2.5032
# q_a_doc2vec          - Как оформляется больничный лист 0.1736
#
# User query:            как сделать пропуск
# Best match:          + Когда требуется оформление пропуска и как это сделать?
# AutoF:               + Когда требуется оформление пропуска и как это сделать?
# q                    + Когда требуется оформление пропуска и как это сделать? 0.3497
# q_a                  + Когда требуется оформление пропуска и как это сделать? 0.422
# q_a_w                + Когда требуется оформление пропуска и как это сделать? 0.4281
# q_unnormed           + Когда требуется оформление пропуска и как это сделать? 1.3544
# q_a_unnormed         + Когда требуется оформление пропуска и как это сделать? 1.5584
# q_a_w_unnormed       + Когда требуется оформление пропуска и как это сделать? 1.5781
# q_a_concat_unnormed  + Когда требуется оформление пропуска и как это сделать? 2.5781
# q_a_doc2vec          - ты отличный собеседник 0.1718
#
# User query:            можно ли не ходить в отпуск
# Best match:          + Обязательно ли сотруднику идти в отпуск?
# AutoF:               + Обязательно ли сотруднику идти в отпуск?
# q                    + Обязательно ли сотруднику идти в отпуск? 0.2813
# q_a                  - Можно ли планировать отпуск на выходные дни? 0.3244
# q_a_w                - Можно ли планировать отпуск на выходные дни? 0.3278
# q_unnormed           + Обязательно ли сотруднику идти в отпуск? 1.1565
# q_a_unnormed         - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.3338
# q_a_w_unnormed       - Можно ли планировать отпуск на выходные дни? 1.3681
# q_a_concat_unnormed  + Обязательно ли сотруднику идти в отпуск? 2.3219
# q_a_doc2vec          - стань умнее 0.1712
#
# User query:            здравствуйте
# Best match:          + привет привет
# AutoF:               + привет привет
# q                    - Где я могу заполнить заявку на работу в выходной день? 0.8626
# q_a                  - ты меня раздражаешь 0.7969
# q_a_w                - ты меня раздражаешь 0.7616
# q_unnormed           - я тебя проверяю 4.224
# q_a_unnormed         - молодец 3.915
# q_a_w_unnormed       - ты меня раздражаешь 3.7931
# q_a_concat_unnormed  - я тебя проверяю 6.3148
# q_a_doc2vec          - Как дела 0.2121
#
# User query:            как получить зарплатную карту
# Best match:          + В каком порядке выдаются зарплатные карты?
# AutoF:               + В каком порядке выдаются зарплатные карты?
# q                    - Как получить денежную компенсацию за дополнительный отпуск? 0.4154
# q_a                  + В каком порядке выдаются зарплатные карты? 0.437
# q_a_w                + В каком порядке выдаются зарплатные карты? 0.4367
# q_unnormed           - Как получить денежную компенсацию за дополнительный отпуск? 1.921
# q_a_unnormed         + В каком порядке выдаются зарплатные карты? 1.8493
# q_a_w_unnormed       + В каком порядке выдаются зарплатные карты? 1.8343
# q_a_concat_unnormed  - Как получить денежную компенсацию за дополнительный отпуск? 3.125
# q_a_doc2vec          - я шучу 0.1436
#
# User query:            можно ли сделать больничный в отпуске
# Best match:          + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год?
# AutoF:               - Обязательно ли сотруднику идти в отпуск?
# q                    + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.3182
# q_a                  + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.3383
# q_a_w                + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.35
# q_unnormed           + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.267
# q_a_unnormed         + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.3697
# q_a_w_unnormed       + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.4152
# q_a_concat_unnormed  + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 2.4016
# q_a_doc2vec          - ты мне очень помогла 0.1317
#
# User query:            как получить копию трудового договора
# Best match:          + Когда и как можно забрать свой экземпляр трудового договора?
# AutoF:               + Когда и как можно забрать свой экземпляр трудового договора?
# q                    + Когда и как можно забрать свой экземпляр трудового договора? 0.3288
# q_a                  + Когда и как можно забрать свой экземпляр трудового договора? 0.3499
# q_a_w                + Когда и как можно забрать свой экземпляр трудового договора? 0.3548
# q_unnormed           + Когда и как можно забрать свой экземпляр трудового договора? 1.441
# q_a_unnormed         + Когда и как можно забрать свой экземпляр трудового договора? 1.5934
# q_a_w_unnormed       + Когда и как можно забрать свой экземпляр трудового договора? 1.6145
# q_a_concat_unnormed  + Когда и как можно забрать свой экземпляр трудового договора? 2.8111
# q_a_doc2vec          - это правда что ты бот 0.1812
#
# User query:            за сколько дней нужно подавать заявку на отпуск?
# Best match:          + За сколько дней можно оформить отпуск?
# AutoF:               - Как запланировать отпуск?
# q                    + За сколько дней можно оформить отпуск? 0.2801
# q_a                  - Можно ли планировать отпуск на выходные дни? 0.3168
# q_a_w                + За сколько дней можно оформить отпуск? 0.3016
# q_unnormed           + За сколько дней можно оформить отпуск? 1.2741
# q_a_unnormed         - Можно ли планировать отпуск на выходные дни? 1.4462
# q_a_w_unnormed       + За сколько дней можно оформить отпуск? 1.3848
# q_a_concat_unnormed  + За сколько дней можно оформить отпуск? 2.5563
# q_a_doc2vec          - ты скучный 0.1203
#
# User query:            сколько дней отпуска можно взять единовременно
# Best match:          + Какое количество дней отпуска можно взять (мин/макс)?
# AutoF:               + Какое количество дней отпуска можно взять (мин/макс)?
# q                    - За сколько дней можно оформить отпуск? 0.2653
# q_a                  - Можно ли планировать отпуск на выходные дни? 0.3258
# q_a_w                + Какое количество дней отпуска можно взять (мин/макс)? 0.3224
# q_unnormed           - За сколько дней можно оформить отпуск? 1.1268
# q_a_unnormed         - Можно ли планировать отпуск на выходные дни? 1.2916
# q_a_w_unnormed       + Какое количество дней отпуска можно взять (мин/макс)? 1.2921
# q_a_concat_unnormed  - За сколько дней можно оформить отпуск? 2.4845
# q_a_doc2vec          - ты скучный 0.0737
#
# User query:            когда выдаются премии?
# Best match:          + Где можно подробнее ознакомиться с правилами годового премирования?
# AutoF:               + Где можно подробнее ознакомиться с правилами годового премирования?
# q                    - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.5166
# q_a                  - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.4972
# q_a_w                - В каком порядке выдаются зарплатные карты? 0.495
# q_unnormed           - В каком порядке выдаются зарплатные карты? 2.4772
# q_a_unnormed         - В каком порядке выдаются зарплатные карты? 2.4517
# q_a_w_unnormed       - В каком порядке выдаются зарплатные карты? 2.4005
# q_a_concat_unnormed  - В каком порядке выдаются зарплатные карты? 3.7593
# q_a_doc2vec          - это правда что ты бот 0.0816
#
# User query:            что делать если я заболел
# Best match:          + Как оформляется больничный лист
# AutoF:               - Какой порядок вынесения работнику дисциплинарного взыскания?
# q                    - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.3845
# q_a                  - уточни о чём ты 0.3792
# q_a_w                - уточни о чём ты 0.3794
# q_unnormed           - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.4783
# q_a_unnormed         - сделай мне одолжение 1.503
# q_a_w_unnormed       - сделай мне одолжение 1.4569
# q_a_concat_unnormed  - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 2.7013
# q_a_doc2vec          - доброе утро 0.1542
#
# User query:            отменяются ли дни отпуска, которые пересекаются с больничным?
# Best match:          + Если во время отпуска работник заболел
# AutoF:               + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести
# q                    + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.3336
# q_a                  + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.3027
# q_a_w                + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.3076
# q_unnormed           + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.3262
# q_a_unnormed         + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.2616
# q_a_w_unnormed       + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.2851
# q_a_concat_unnormed  + Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 2.3778
# q_a_doc2vec          - Что в тебя загружено 0.1436
#
# User query:            можно ли оформить отпуск на выходные?
# Best match:          + Можно ли планировать отпуск на выходные дни?
# AutoF:               + Можно ли планировать отпуск на выходные дни?
# q                    + Можно ли планировать отпуск на выходные дни? 0.2198
# q_a                  + Можно ли планировать отпуск на выходные дни? 0.3369
# q_a_w                + Можно ли планировать отпуск на выходные дни? 0.344
# q_unnormed           + Можно ли планировать отпуск на выходные дни? 0.9841
# q_a_unnormed         + Можно ли планировать отпуск на выходные дни? 1.4405
# q_a_w_unnormed       + Можно ли планировать отпуск на выходные дни? 1.4688
# q_a_concat_unnormed  + Можно ли планировать отпуск на выходные дни? 2.5033
# q_a_doc2vec          - это правда что ты бот 0.2268
#
# User query:            даются ли отгулы за сдачу крови?
# Best match:          + Отпуск для доноров: сколько дней полагается и как они оплачиваются?
# AutoF:               - Возможна ли денежная компенсация за неиспользованный отпуск?
# q                    - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.3965
# q_a                  + Отпуск для доноров: сколько дней полагается и как они оплачиваются? 0.3701
# q_a_w                + Отпуск для доноров: сколько дней полагается и как они оплачиваются? 0.3635
# q_unnormed           - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.7522
# q_a_unnormed         + Отпуск для доноров: сколько дней полагается и как они оплачиваются? 1.6504
# q_a_w_unnormed       + Отпуск для доноров: сколько дней полагается и как они оплачиваются? 1.6206
# q_a_concat_unnormed  + Отпуск для доноров: сколько дней полагается и как они оплачиваются? 2.8867
# q_a_doc2vec          - ты мне очень помогла 0.167
#
# User query:            есть ли дополнительный отпуск тем, кто работал в Чернобыле?
# Best match:          + Как оформяется отпуск чернобыльцам?
# AutoF:               - ты кто
# q                    - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.2959
# q_a                  - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 0.2894
# q_a_w                + Как оформяется отпуск чернобыльцам? 0.2841
# q_unnormed           - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 1.2075
# q_a_unnormed         + Как оформяется отпуск чернобыльцам? 1.1717
# q_a_w_unnormed       + Как оформяется отпуск чернобыльцам? 1.1314
# q_a_concat_unnormed  - Если во время отпуска работник заболел, получил листок нетрудоспособности, можно ли перенести, то есть «догулять» положенные дни. Если да — как это сделать и переносятся ли эти дни на следующий год? 2.1905
# q_a_doc2vec          - ты скучный 0.1281
#
#
# Scores (17 questions):
# 11 AutoF
# 9 q
# 9 q_unnormed
# 10 q_a_concat_unnormed
# 8 q_a
# 11 q_a_w
# 9 q_a_unnormed
# 11 q_a_w_unnormed
